# %% [markdown]
# <a href="https://colab.research.google.com/github/SohaMubashir/dataAnalytics_portfolio/blob/main/K_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.cluster import KMeans

# %%
import matplotlib.pyplot as plt

# %%
data = {
    'Age': [20,30,40,22,38,25],
    'Spending' : [100,200,300,110,290,130]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Age  Spending
# 0   20       100
# 1   30       200
# 2   40       300
# 3   22       110
# 4   38       290
# 5   25       130

# %%
x = df[['Age','Spending']]

# %%
model = KMeans(n_clusters=2, random_state=42,n_init=10)

# %%
df['Group'] = model.fit_predict(x)

# %%
plt.figure(figsize=(10,6))
for group in df['Group'].unique():
  cluster_data = df[df['Group'] == group]
  plt.scatter(cluster_data['Age'],cluster_data['Spending'],label=f'Group {group}')

plt.xlabel('Age')
plt.ylabel('Spending')
plt.title('Customer Segmentation (K-Means)')
plt.legend()
plt.show()
